# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import math
import scipy.optimize
from sympy.solvers.diophantine import diophantine
from sympy import symbols
from sympy import Symbol, solve 
from sympy import diff, symbols, cos, sin
from sympy import *


eps = 0.001
x1 = 42
x2 = 11
h = 0


def f(x1, x2): 
    return 100 * (x2-x1**3)**2 + (1-x1)**2

def grad_x1(x1, x2): #аналитический метод наождения частной производной
    return -600 * (x1 ** 2) *(x2 - x1 ** 3) + 2  * x1 - 2
   
def grad_x2(x1,x2): #аналитический метод наождения частной производной
    return -200 * x1 ** 3 + 200 * x2
#print (grad_x2(x1,x2))


def ret_grad(x1, x2, grad_x1, grad_x2): #находим шаг   
    k = Symbol("k") 
    x1_2 = x1 - k * grad_x1(x1, x2)
    x2_2 = x2 - k * grad_x2(x1, x2)
    pr = diff ((x1_2 ** 2 + x2_2 ** 2 + (3 * x1_2 * x2_2) / 2 ))
    k = solve(pr)
    b = [float(i) for i in k]

    k1 = b[0]
    x1_2 = x1 - k1 * grad_x1(x1, x2) 
    x2_2 = x2 - k1 * grad_x2(x1, x2)

#    print ('Шаг: ', k1) 
    return k1
#print ('Шаг: ',ret_grad(x1, x2, grad_x1, grad_x2))

def chast_diff_x1x2 (x1, x2, x1_0, x2_0): #численный метод нахождения частной производной
    x1, x2 = symbols('x1 x2')
    chast_diff_x1 = diff(100 * (x2-x1**3)**2 + (1-x1)**2, x1)
    chast_diff_x2 = diff(100 * (x2-x1**3)**2 + (1-x1)**2, x2)    
#    print ('Частная призводная по х1: ', chast_diff_x1)
#    print ('Частная призводная по х2: ', chast_diff_x2)
    
    chast_diff_x1 = chast_diff_x1.subs ({x1: x1_0, x2: x2_0}) #значение градиента
    chast_diff_x2 = chast_diff_x2.subs ({x1: x1_0, x2: x2_0})
    
    return chast_diff_x1,chast_diff_x2 

#print ('Значение градиента: ',chast_diff_x1x2 (x1, x2, x1, x2))
 
def new_x1x2 (x1, x2, ret_grad, chast_diff_x1x2):
    x1_2 = x1 - ret_grad(x1, x2, grad_x1, grad_x2) * chast_diff_x1x2(x1, x2, x1, x2)[0]
    x2_2 = x2 - ret_grad(x1, x2, grad_x1, grad_x2) * chast_diff_x1x2(x1, x2, x1, x2)[1]
    #print (f(x1_2, x2_2))
    return (x1_2, x2_2)
    
#print ('Значение новый переменных: ', new_x1x2( x1, x2, ret_grad, chast_diff_x1x2))

#a = new_x1x2(x1, x2, ret_grad, chast_diff_x1x2)
#print (a)
#print(f(a[0],a[1]))

def task (x1, x2, ret_grad, chast_diff_x1x2, new_x1x2,f):
    k=1
    while (True):
        print('k =', k)
        print(' x1 =', x1)
        print(' x2 =', x2)
        print(' Значение функции в этой точке = ' , f(x1,x2))
        ret_grad(x1, x2, grad_x1, grad_x2)
        print(' Шаг = ', ret_grad(x1, x2, grad_x1, grad_x2))
        chast_diff_x1x2(x1, x2, x1, x2)
        print(' Градиент:' , chast_diff_x1x2(x1, x2, x1, x2))
        a = new_x1x2(x1, x2, ret_grad, chast_diff_x1x2)
        print(' Новые точки:' , new_x1x2(x1, x2, ret_grad, chast_diff_x1x2))
        if abs ( f(new_x1x2(x1, x2, ret_grad, chast_diff_x1x2)[0], new_x1x2(x1, x2, ret_grad, chast_diff_x1x2)[1]) - f(x1, x2)) < eps :
            break
        
        x1=a[0]
        x2=a[1]
        k+=1
    print (x1, x2, f(x1,x2))
        
print(task (x1, x2, ret_grad, chast_diff_x1x2, new_x1x2,f))
# Out:
# k = 1
#  x1 = 42
#  x2 = 11
#  Значение функции в этой точке =  548740194581
#  Шаг =  6.409977943732132e-10
#  Градиент: (78403096882, -14815400)
#  Новые точки: (-8.25621217339135, 11.0094966387228)
# k = 2
#  x1 = -8.25621217339135
#  x2 = 11.0094966387228
#  Значение функции в этой точке =  32924101.3881079
#  Шаг =  9.721336575334866e-10
#  Градиент: (-23467654.3794689, 114758.905032497)
#  Новые точки: (-8.23339847670570, 11.0093850777287)
# k = 3
#  x1 = -8.23339847670570
#  x2 = 11.0093850777287
#  Значение функции в этой точке =  32392347.2506711
#  Шаг =  5.7091931193415555e-12
#  Градиент: (-23148907.7647292, 113828.400665253)
#  Новые точки: (-8.23326631512077, 11.0093844278604)
# k = 4
#  x1 = -8.23326631512077
#  x2 = 11.0093844278604
#  Значение функции в этой точке =  32389287.9017066
#  Шаг =  3.321546302588259e-14
#  Градиент: (-23147071.4433569, 113823.025172414)
#  Новые точки: (-8.23326554628007, 11.0093844240797)
# k = 5
#  x1 = -8.23326554628007
#  x2 = 11.0093844240797
#  Значение функции в этой точке =  32389270.1048699
#  Шаг =  1.9323341771272323e-16
#  Градиент: (-23147060.7610298, 113822.993901368)
#  Новые точки: (-8.23326554180729, 11.0093844240577)
# k = 6
#  x1 = -8.23326554180729
#  x2 = 11.0093844240577
#  Значение функции в этой точке =  32389270.0013356
#  Шаг =  1.1240717118958787e-18
#  Градиент: (-23147060.6988846, 113822.993719447)
#  Новые точки: (-8.23326554178127, 11.0093844240575)
# -8.23326554180729 11.0093844240577 32389270.0013356
# None
