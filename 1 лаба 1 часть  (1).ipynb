# %% [markdown]
# Зададим функцию

# %%
def f(x):
    return (x-15)**2+5

# %%
a = 2
b = 200
e=0.01
d=0.001

# %% [markdown]
# Метод дихотомии (деления отрезка пополам)

# %%
def dichotomy(f, a, b):
    k = 1
    count = 0
    while (b-a)>e:
        middle = (a+b)/2
        x1 = middle-d
        x2 = middle+d 
        print('k =', k) 
        print(' Интервал нахождения минимума функции:', '[', a, ',', b, ']', '\n Длина интервала: ', b-a)
        print(' Середина интервала =', middle, '\n Значение функции в середине интервала =', f(middle))
        print(' x1 =', x1, '\n Значение функции в x1 =', f(x1))        
        print(' x2 =', x2, '\n Значение функции в x2 =', f(x2), '\n')        
        if f(x1)>f(x2):
            a = x1
        else:
            b = x2 
        k += 1
        count +=2
    print ('Ответ:\n xmin =', middle)
    print (' значение функции в xmin =', f(middle), '\n') 
    return a, b, b-a, count

print(dichotomy(f, a, b))
# Out:
# k = 1
#  Интервал нахождения минимума функции: [ 2 , 200 ]
#  Длина интервала:  198
#  Середина интервала = 101.0
#  Значение функции в середине интервала = 7401.0
#  x1 = 100.999
#  Значение функции в x1 = 7400.828000999999
#  x2 = 101.001
#  Значение функции в x2 = 7401.172001000001
#
# k = 2
#  Интервал нахождения минимума функции: [ 2 , 101.001 ]
#  Длина интервала:  99.001
#  Середина интервала = 51.5005
#  Значение функции в середине интервала = 1337.2865002500002
#  x1 = 51.499500000000005
#  Значение функции в x1 = 1337.2135002500004
#  x2 = 51.5015
#  Значение функции в x2 = 1337.35950225
#
# k = 3
#  Интервал нахождения минимума функции: [ 2 , 51.5015 ]
#  Длина интервала:  49.5015
#  Середина интервала = 26.75075
#  Значение функции в середине интервала = 143.0801255625
#  x1 = 26.74975
#  Значение функции в x1 = 143.05662506249996
#  x2 = 26.75175
#  Значение функции в x2 = 143.10362806250004
#
# k = 4
#  Интервал нахождения минимума функции: [ 2 , 26.75175 ]
#  Длина интервала:  24.75175
#  Середина интервала = 14.375875
#  Значение функции в середине интервала = 5.389532015624999
#  x1 = 14.374875000000001
#  Значение функции в x1 = 5.390781265624999
#  x2 = 14.376875
#  Значение функции в x2 = 5.388284765625
#
# k = 5
#  Интервал нахождения минимума функции: [ 14.374875000000001 , 26.75175 ]
#  Длина интервала:  12.376875
#  Середина интервала = 20.563312500000002
#  Значение функции в середине интервала = 35.95044597265627
#  x1 = 20.5623125
#  Значение функции в x1 = 35.93932034765626
#  x2 = 20.564312500000003
#  Значение функции в x2 = 35.96157359765628
#
# k = 6
#  Интервал нахождения минимума функции: [ 14.374875000000001 , 20.564312500000003 ]
#  Длина интервала:  6.189437500000002
#  Середина интервала = 17.46959375
#  Значение функции в середине интервала = 11.098893290039069
#  x1 = 17.46859375
#  Значение функции в x1 = 11.093955102539063
#  x2 = 17.470593750000003
#  Значение функции в x2 = 11.103833477539077
#
# k = 7
#  Интервал нахождения минимума функции: [ 14.374875000000001 , 17.470593750000003 ]
#  Длина интервала:  3.0957187500000014
#  Середина интервала = 15.922734375000001
#  Значение функции в середине интервала = 5.851438726806642
#  x1 = 15.921734375000002
#  Значение функции в x1 = 5.849594258056643
#  x2 = 15.923734375
#  Значение функции в x2 = 5.853285195556642
#
# k = 8
#  Интервал нахождения минимума функции: [ 14.374875000000001 , 15.923734375 ]
#  Длина интервала:  1.5488593749999993
#  Середина интервала = 15.1493046875
#  Значение функции в середине интервала = 5.022291889709473
#  x1 = 15.148304687500001
#  Значение функции в x1 = 5.021994280334473
#  x2 = 15.1503046875
#  Значение функции в x2 = 5.022591499084473
#
# k = 9
#  Интервал нахождения минимума функции: [ 14.374875000000001 , 15.1503046875 ]
#  Длина интервала:  0.7754296874999991
#  Середина интервала = 14.76258984375
#  Значение функции в середине интервала = 5.05636358229065
#  x1 = 14.76158984375
#  Значение функции в x1 = 5.056839402603149
#  x2 = 14.76358984375
#  Значение функции в x2 = 5.0558897619781495
#
# k = 10
#  Интервал нахождения минимума функции: [ 14.76158984375 , 15.1503046875 ]
#  Длина интервала:  0.38871484374999987
#  Середина интервала = 14.955947265625
#  Значение функции в середине интервала = 5.001940643405915
#  x1 = 14.954947265625
#  Значение функции в x1 = 5.002029748874664
#  x2 = 14.956947265624999
#  Значение функции в x2 = 5.001853537937165
#
# k = 11
#  Интервал нахождения минимума функции: [ 14.954947265625 , 15.1503046875 ]
#  Длина интервала:  0.19535742187500027
#  Середина интервала = 15.0526259765625
#  Значение функции в середине интервала = 5.002769493409157
#  x1 = 15.0516259765625
#  Значение функции в x1 = 5.0026652414560315
#  x2 = 15.053625976562499
#  Значение функции в x2 = 5.002875745362282
#
# k = 12
#  Интервал нахождения минимума функции: [ 14.954947265625 , 15.053625976562499 ]
#  Длина интервала:  0.09867871093749869
#  Середина интервала = 15.00428662109375
#  Значение функции в середине интервала = 5.000018375120401
#  x1 = 15.00328662109375
#  Значение функции в x1 = 5.000010801878214
#  x2 = 15.005286621093749
#  Значение функции в x2 = 5.000027948362589
#
# k = 13
#  Интервал нахождения минимума функции: [ 14.954947265625 , 15.005286621093749 ]
#  Длина интервала:  0.05033935546874879
#  Середина интервала = 14.980116943359373
#  Значение функции в середине интервала = 5.000395335941374
#  x1 = 14.979116943359374
#  Значение функции в x1 = 5.000436102054656
#  x2 = 14.981116943359373
#  Значение функции в x2 = 5.000356569828093
#
# k = 14
#  Интервал нахождения минимума функции: [ 14.979116943359374 , 15.005286621093749 ]
#  Длина интервала:  0.02616967773437473
#  Середина интервала = 14.992201782226562
#  Значение функции в середине интервала = 5.0000608122004415
#  x1 = 14.991201782226563
#  Значение функции в x1 = 5.000077408635989
#  x2 = 14.993201782226562
#  Значение функции в x2 = 5.000046215764895
#
# k = 15
#  Интервал нахождения минимума функции: [ 14.991201782226563 , 15.005286621093749 ]
#  Длина интервала:  0.014084838867185923
#  Середина интервала = 14.998244201660157
#  Значение функции в середине интервала = 5.00000308282781
#  x1 = 14.997244201660157
#  Значение функции в x1 = 5.00000759442449
#  x2 = 14.999244201660156
#  Значение функции в x2 = 5.000000571231131
#
# Ответ:
#  xmin = 14.998244201660157
#  значение функции в xmin = 5.00000308282781
#
# (14.997244201660157, 15.005286621093749, 0.008042419433591519, 30)

# %% [markdown]
#  Метод золотого сечения

# %%
import math 

def golden(a, b, f):
    k = 1
    c = 0
    while (b - a) > e:
        x1 = a + 0.381966011*(b-a)
        x2 = a + 0.618003399*(b-a)
        print('k =', k) 
        print(' Интервал нахождения минимума функции:', '[', a, ',', b, ']', '\n Длина интервала: ', b-a)
        print(' x1 =', x1, '\n Значение функции в x1 =', f(x1))
        print(' x2 =', x2, '\n Значение функции в x2 =', f(x2), '\n')
        if f(x1) < f(x2):
            b = x2
        else:
            a = x1        
        k += 1
        c += 2
        
    print ('Ответ:\n xmin =', (b+a)/2)
    print (' значение функции в xmin =', f((b+a)/2), '\n') 
    return a, b, b-a, c 

print(golden(a, b, f))
# Out:
# k = 1
#  Интервал нахождения минимума функции: [ 2 , 200 ]
#  Длина интервала:  198
#  x1 = 77.629270178
#  Значение функции в x1 = 3927.42548302892
#  x2 = 124.364673002
#  Значение функции в x2 = 11965.631700834389
#
# k = 2
#  Интервал нахождения минимума функции: [ 2 , 124.364673002 ]
#  Длина интервала:  122.364673002
#  x1 = 48.739146033893334
#  Значение функции в x1 = 1143.3299750963804
#  x2 = 77.62178383275953
#  Значение функции в x2 = 3926.487810396863
#
# k = 3
#  Интервал нахождения минимума функции: [ 2 , 77.62178383275953 ]
#  Длина интервала:  75.62178383275953
#  x1 = 30.88495111530345
#  Значение функции в x1 = 257.3316719355804
#  x2 = 48.73451944708864
#  Значение функции в x2 = 1143.0178023260014
#
# k = 4
#  Интервал нахождения минимума функции: [ 2 , 48.73451944708864 ]
#  Длина интервала:  46.73451944708864
#  x1 = 19.85099796920637
#  Значение функции в x1 = 28.532181297244342
#  x2 = 30.882091868932378
#  Значение функции в x2 = 257.24084213320793
#
# k = 5
#  Интервал нахождения минимума функции: [ 2 , 30.882091868932378 ]
#  Длина интервала:  28.882091868932378
#  x1 = 13.031977420511636
#  Значение функции в x1 = 8.873112873376035
#  x2 = 19.849230945230474
#  Значение функции в x2 = 28.515040760180835
#
# k = 6
#  Интервал нахождения минимума функции: [ 2 , 19.849230945230474 ]
#  Длина интервала:  17.849230945230474
#  x1 = 8.817799543567443
#  Значение функции в x1 = 43.21960248351492
#  x2 = 13.030885393688417
#  Значение функции в x2 = 8.877412332789621
#
# k = 7
#  Интервал нахождения минимума функции: [ 8.817799543567443 , 19.849230945230474 ]
#  Длина интервала:  11.031431401663031
#  x1 = 13.031431391680808
#  Значение функции в x1 = 8.87526236565976
#  x2 = 15.63526164563053
#  Значение функции в x2 = 5.403557358409209
#
# k = 8
#  Интервал нахождения минимума функции: [ 13.031431391680808 , 19.849230945230474 ]
#  Длина интервала:  6.817799553549666
#  x1 = 15.635599090947755
#  Значение функции в x1 = 5.403986204413613
#  x2 = 17.244854689475183
#  Значение функции в x2 = 10.03937257685872
#
# k = 9
#  Интервал нахождения минимума функции: [ 13.031431391680808 , 17.244854689475183 ]
#  Длина интервала:  4.213423297794375
#  x1 = 14.64081588139379
#  Значение функции в x1 = 5.12901323105892
#  x2 = 15.63534131114352
#  Значение функции в x2 = 5.403658581645567
#
# k = 10
#  Интервал нахождения минимума функции: [ 13.031431391680808 , 15.63534131114352 ]
#  Длина интервала:  2.603909919462712
#  x1 = 14.02603647662131
#  Значение функции в x1 = 5.948604944872231
#  x2 = 14.64065657259858
#  Значение функции в x2 = 5.1291276988166
#
# k = 11
#  Интервал нахождения минимума функции: [ 14.02603647662131 , 15.63534131114352 ]
#  Длина интервала:  1.6093048345222094
#  x1 = 14.640736224746774
#  Значение функции в x1 = 5.1290704602092
#  x2 = 15.020592334383169
#  Значение функции в x2 = 5.0004240442353485
#
# k = 12
#  Интервал нахождения минимума функции: [ 14.640736224746774 , 15.63534131114352 ]
#  Длина интервала:  0.9946050863967457
#  x1 = 15.02064156211805
#  Значение функции в x1 = 5.000426074086674
#  x2 = 15.255405548802653
#  Значение функции в x2 = 5.065231994359184
#
# k = 13
#  Интервал нахождения минимума функции: [ 14.640736224746774 , 15.255405548802653 ]
#  Длина интервала:  0.6146693240558783
#  x1 = 14.875519014540465
#  Значение функции в x1 = 5.015495515740977
#  x2 = 15.02060395627434
#  Значение функции в x2 = 5.000424523014155
#
# k = 14
#  Интервал нахождения минимума функции: [ 14.875519014540465 , 15.255405548802653 ]
#  Длина интервала:  0.3798865342621873
#  x1 = 15.020622758665208
#  Значение функции в x1 = 5.000425298174964
#  x2 = 15.110290183948827
#  Значение функции в x2 = 5.012163924675466
#
# k = 15
#  Интервал нахождения минимума функции: [ 14.875519014540465 , 15.110290183948827 ]
#  Длина интервала:  0.2347711694083614
#  x1 = 14.965193621617182
#  Значение функции в x1 = 5.001211483976128
#  x2 = 15.020608395222038
#  Значение функции в x2 = 5.000424705953628
#
# k = 16
#  Интервал нахождения минимума функции: [ 14.965193621617182 , 15.110290183948827 ]
#  Длина интервала:  0.14509656233164492
#  x1 = 15.020615576740813
#  Значение функции в x1 = 5.000425002004357
#  x2 = 15.054863790321354
#  Значение функции в x2 = 5.003010035488425
#
# k = 17
#  Интервал нахождения минимума функции: [ 14.965193621617182 , 15.054863790321354 ]
#  Длина интервала:  0.08967016870417233
#  x1 = 14.999444578262812
#  Значение функции в x1 = 5.0000003084933065
#  x2 = 15.020610090665263
#  Значение функции в x2 = 5.000424775837231
#
# k = 18
#  Интервал нахождения минимума функции: [ 14.965193621617182 , 15.020610090665263 ]
#  Длина интервала:  0.055416469048081396
#  x1 = 14.986360829243182
#  Значение функции в x1 = 5.000186026978934
#  x2 = 14.999441187849474
#  Значение функции в x2 = 5.00000031227102
#
# k = 19
#  Интервал нахождения минимума функции: [ 14.986360829243182 , 15.020610090665263 ]
#  Длина интервала:  0.03424926142208129
#  x1 = 14.999442883008271
#  Значение функции в x1 = 5.000000310379343
#  x2 = 15.007526989215268
#  Значение функции в x2 = 5.000056655566647
#
# k = 20
#  Интервал нахождения минимума функции: [ 14.986360829243182 , 15.007526989215268 ]
#  Длина интервала:  0.021166159972086263
#  x1 = 14.994445582935908
#  Значение функции в x1 = 5.000030851548922
#  x2 = 14.99944158804971
#  Значение функции в x2 = 5.000000311823906
#
# k = 21
#  Интервал нахождения минимума функции: [ 14.994445582935908 , 15.007526989215268 ]
#  Длина интервала:  0.013081406279360053
#  x1 = 14.999442235510706
#  Значение функции в x1 = 5.000000311101226
#  x2 = 15.002529936480252
#  Значение функции в x2 = 5.000006400578594
#
# Ответ:
#  xmin = 14.99848775970808
#  значение функции в xmin = 5.000002286870701
#
# (14.994445582935908, 15.002529936480252, 0.008084353544344225, 42)

# %% [markdown]
# Метод Фибоначчи

# %%
from math import sqrt 
def F(n): 
    return ((1+sqrt(5))**n-(1-sqrt(5))**n)/(2**n*sqrt(5))

# %%
Fmax=((b-a)/e)
F1 = 1
F2 = 1
Fn = 0
n = 2
while (Fmax > Fn):
    Fn = F1 + F2
    F1 = F2
    F2 = Fn
    n += 1
print(n)
# Out:
# 23

# %%
def fibonachchi(a, b, f):
    k=1
    count =0
    n=21
    x1 = a + (F(n)/F(n+2))*(b-a)
    x2 = a + (F(n+1)/F(n+2))*(b-a)
    while k!=n+1:
        print('k =', k) 
        print(' Интервал нахождения минимума функции:', '[', a, ',', b, ']', '\n Длина интервала: ', b-a)
        print(' x1 =', x1, '\n Значение функции в x1 =', f(x1))
        print(' x2 =', x2, '\n Значение функции в x2 =', f(x2), '\n')
        if f(x1)>f(x2):
            a=x1
            x1=x2
            x2=a+(F(n-k+2)/F(n+2))*(200-2)
        else:
            b=x2
            x2=x1
            x1=a+(F(n-k+1)/F(n+2))*(200-2)
        k += 1 
        count +=2
    
    print ('Ответ:\n xmin =', (b+a)/2)
    print (' значение функции в xmin =', f((b+a)/2), '\n') 
    print ('x1 =', x1, 'x2 =', x2)
    return a, b, b-a , count
    
print(fibonachchi(a, b, f))
# Out:
# k = 1
#  Интервал нахождения минимума функции: [ 2 , 200 ]
#  Длина интервала:  198
#  x1 = 77.62927033534564
#  Значение функции в x1 = 3927.425502737805
#  x2 = 124.37072966465435
#  Значение функции в x2 = 11966.956507378904
#
# k = 2
#  Интервал нахождения минимума функции: [ 2 , 124.37072966465435 ]
#  Длина интервала:  122.37072966465435
#  x1 = 77.62927033534564
#  Значение функции в x1 = 3927.425502737805
#  x2 = 77.62927033534564
#  Значение функции в x2 = 3927.425502737805
#
# k = 3
#  Интервал нахождения минимума функции: [ 2 , 77.62927033534564 ]
#  Длина интервала:  75.62927033534564
#  x1 = 48.74145932930872
#  Значение функции в x1 = 1143.4860776713942
#  x2 = 77.62927033534564
#  Значение функции в x2 = 3927.425502737805
#
# k = 4
#  Интервал нахождения минимума функции: [ 2 , 77.62927033534564 ]
#  Длина интервала:  75.62927033534564
#  x1 = 30.887811006036916
#  Значение функции в x1 = 257.42253856354773
#  x2 = 48.74145932930872
#  Значение функции в x2 = 1143.4860776713942
#
# k = 5
#  Интервал нахождения минимума функции: [ 2 , 48.74145932930872 ]
#  Длина интервала:  46.74145932930872
#  x1 = 19.8536483232718
#  Значение функции в x1 = 28.55790204599914
#  x2 = 30.887811006036916
#  Значение функции в x2 = 257.42253856354773
#
# k = 6
#  Интервал нахождения минимума функции: [ 2 , 30.887811006036916 ]
#  Длина интервала:  28.887811006036916
#  x1 = 13.034162682765116
#  Значение функции в x1 = 8.864516357833246
#  x2 = 19.8536483232718
#  Значение функции в x2 = 28.55790204599914
#
# k = 7
#  Интервал нахождения минимума функции: [ 2 , 19.8536483232718 ]
#  Длина интервала:  17.8536483232718
#  x1 = 8.81948564050668
#  Значение функции в x1 = 43.198757747903116
#  x2 = 13.034162682765116
#  Значение функции в x2 = 8.864516357833246
#
# k = 8
#  Интервал нахождения минимума функции: [ 8.81948564050668 , 19.8536483232718 ]
#  Длина интервала:  11.034162682765118
#  x1 = 13.034162682765116
#  Значение функции в x1 = 8.864516357833246
#  x2 = 15.638971281013362
#  Значение функции в x2 = 5.408284297959856
#
# k = 9
#  Интервал нахождения минимума функции: [ 13.034162682765116 , 19.8536483232718 ]
#  Длина интервала:  6.819485640506683
#  x1 = 15.638971281013362
#  Значение функции в x1 = 5.408284297959856
#  x2 = 17.24883972502355
#  Значение функции в x2 = 10.057280108844
#
# k = 10
#  Интервал нахождения минимума функции: [ 13.034162682765116 , 17.24883972502355 ]
#  Длина интервала:  4.214677042258435
#  x1 = 14.644031126775305
#  Значение функции в x1 = 5.126713838704859
#  x2 = 15.638971281013362
#  Значение функции в x2 = 5.408284297959856
#
# k = 11
#  Интервал нахождения минимума функции: [ 13.034162682765116 , 15.638971281013362 ]
#  Длина интервала:  2.604808598248246
#  x1 = 14.029102837003173
#  Значение функции в x1 = 5.942641301115288
#  x2 = 14.644031126775305
#  Значение функции в x2 = 5.126713838704859
#
# k = 12
#  Интервал нахождения минимума функции: [ 14.029102837003173 , 15.638971281013362 ]
#  Длина интервала:  1.6098684440101891
#  x1 = 14.644031126775305
#  Значение функции в x1 = 5.126713838704859
#  x2 = 15.02404299124123
#  Значение функции в x2 = 5.000578065427826
#
# k = 13
#  Интервал нахождения минимума функции: [ 14.644031126775305 , 15.638971281013362 ]
#  Длина интервала:  0.9949401542380567
#  x1 = 15.02404299124123
#  Значение функции в x1 = 5.000578065427826
#  x2 = 15.258959416547437
#  Значение функции в x2 = 5.067059979418589
#
# k = 14
#  Интервал нахождения минимума функции: [ 14.644031126775305 , 15.258959416547437 ]
#  Длина интервала:  0.6149282897721324
#  x1 = 14.878947552081513
#  Значение функции в x1 = 5.014653695147058
#  x2 = 15.02404299124123
#  Значение функции в x2 = 5.000578065427826
#
# k = 15
#  Интервал нахождения минимума функции: [ 14.878947552081513 , 15.258959416547437 ]
#  Длина интервала:  0.3800118644659243
#  x1 = 15.02404299124123
#  Значение функции в x1 = 5.000578065427826
#  x2 = 15.113863977387721
#  Значение функции в x2 = 5.012965005346551
#
# k = 16
#  Интервал нахождения минимума функции: [ 14.878947552081513 , 15.113863977387721 ]
#  Длина интервала:  0.23491642530620815
#  x1 = 14.968768538228005
#  Значение функции в x1 = 5.000975404204415
#  x2 = 15.02404299124123
#  Значение функции в x2 = 5.000578065427826
#
# k = 17
#  Интервал нахождения минимума функции: [ 14.968768538228005 , 15.113863977387721 ]
#  Длина интервала:  0.14509543915971612
#  x1 = 15.02404299124123
#  Значение функции в x1 = 5.000578065427826
#  x2 = 15.058589524374497
#  Значение функции в x2 = 5.00343273236643
#
# k = 18
#  Интервал нахождения минимума функции: [ 14.968768538228005 , 15.058589524374497 ]
#  Длина интервала:  0.08982098614649203
#  x1 = 15.003315071361271
#  Значение функции в x1 = 5.00001098969813
#  x2 = 15.02404299124123
#  Значение функции в x2 = 5.000578065427826
#
# k = 19
#  Интервал нахождения минимума функции: [ 14.968768538228005 , 15.02404299124123 ]
#  Длина интервала:  0.05527445301322409
#  x1 = 14.989496458107965
#  Значение функции в x1 = 5.000110324392278
#  x2 = 15.003315071361271
#  Значение функции в x2 = 5.00001098969813
#
# k = 20
#  Интервал нахождения минимума функции: [ 14.989496458107965 , 15.02404299124123 ]
#  Длина интервала:  0.03454653313326439
#  x1 = 15.003315071361271
#  Значение функции в x1 = 5.00001098969813
#  x2 = 15.010224377987925
#  Значение функции в x2 = 5.00010453790524
#
# k = 21
#  Интервал нахождения минимума функции: [ 14.989496458107965 , 15.010224377987925 ]
#  Длина интервала:  0.0207279198799597
#  x1 = 14.996405764734618
#  Значение функции в x1 = 5.000012918527143
#  x2 = 15.003315071361271
#  Значение функции в x2 = 5.00001098969813
#
# Ответ:
#  xmin = 15.003315071361271
#  значение функции в xmin = 5.00001098969813
#
# x1 = 15.003315071361271 x2 = 15.003315071361271
# (14.996405764734618, 15.010224377987925, 0.013818613253306467, 42)
